# %%
# !pip install kagglehub[pandas-datasets]
# Out:
# Collecting kagglehub[pandas-datasets]
#   Using cached kagglehub-0.3.13-py3-none-any.whl.metadata (38 kB)
# Requirement already satisfied: packaging in ./.venv/lib/python3.12/site-packages (from kagglehub[pandas-datasets]) (25.0)
# Requirement already satisfied: pyyaml in ./.venv/lib/python3.12/site-packages (from kagglehub[pandas-datasets]) (6.0.3)
# Requirement already satisfied: requests in ./.venv/lib/python3.12/site-packages (from kagglehub[pandas-datasets]) (2.32.5)
# Requirement already satisfied: tqdm in ./.venv/lib/python3.12/site-packages (from kagglehub[pandas-datasets]) (4.67.1)
# Requirement already satisfied: pandas in ./.venv/lib/python3.12/site-packages (from kagglehub[pandas-datasets]) (2.3.3)
# Requirement already satisfied: numpy>=1.26.0 in ./.venv/lib/python3.12/site-packages (from pandas->kagglehub[pandas-datasets]) (2.2.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./.venv/lib/python3.12/site-packages (from pandas->kagglehub[pandas-datasets]) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in ./.venv/lib/python3.12/site-packages (from pandas->kagglehub[pandas-datasets]) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in ./.venv/lib/python3.12/site-packages (from pandas->kagglehub[pandas-datasets]) (2025.2)
# Requirement already satisfied: six>=1.5 in ./.venv/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas->kagglehub[pandas-datasets]) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in ./.venv/lib/python3.12/site-packages (from requests->kagglehub[pandas-datasets]) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in ./.venv/lib/python3.12/site-packages (from requests->kagglehub[pandas-datasets]) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./.venv/lib/python3.12/site-packages (from requests->kagglehub[pandas-datasets]) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in ./.venv/lib/python3.12/site-packages (from requests->kagglehub[pandas-datasets]) (2025.10.5)
# Using cached kagglehub-0.3.13-py3-none-any.whl (68 kB)
# Installing collected packages: kagglehub
# Successfully installed kagglehub-0.3.13

# %%
# # pip install kagglehub[pandas-datasets]
import kagglehub
#this is working
path = kagglehub.dataset_download("computingvictor/transactions-fraud-datasets")

print("Path to dataset files:", path)
# Out:
# Downloading from https://www.kaggle.com/api/v1/datasets/download/computingvictor/transactions-fraud-datasets?dataset_version_number=1...
# 100%|██████████| 348M/348M [00:03<00:00, 103MB/s]
# Extracting files...
# Path to dataset files: /home/coder/.cache/kagglehub/datasets/computingvictor/transactions-fraud-datasets/versions/1

# %%
# start here

# %%
# Install dependencies as needed:

# from kagglehub import KaggleDatasetAdapter

# # Set the path to the file you'd like to load
# file_path = "/home/coder/data"
# kagglehub.login()
# # Load the latest version
# df = kagglehub.dataset_load(
#   KaggleDatasetAdapter.PANDAS,
#   "computingvictor/transactions-fraud-datasets",
#   file_path,
#   # Provide any additional arguments like 
#   # sql_query or pandas_kwargs. See the 
#   # documenation for more information:
#   # https://github.com/Kaggle/kagglehub/blob/main/README.md#kaggledatasetadapterpandas
# )

# print("First 5 records:", df.head())

# %%
#this is working

# Download latest version
# path = kagglehub.dataset_download("computingvictor/transactions-fraud-datasets")

# print("Path to dataset files:", path)
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://www.kaggle.com/static/images/site-logo.png\nalt=\'Kaggle…

# %%
import pandas as pd
#df = pd.read_csv ('/home/coder/data/1/transactions_data.csv', nrows=100000)

# %%
import os

# %%
path ='/home/coder/data/1'
os.listdir('/home/coder/data/1')
# Out:
# ['users_data.csv',
#  'mcc_codes.json',
#  'cards_data.csv',
#  'transactions_data.csv',
#  'train_fraud_labels.json']

# %%
mcc_codes = pd.read_json(
    os.path.join(path, "mcc_codes.json"),
    orient="index"
)

mcc_codes.reset_index(inplace=True)
mcc_codes.columns = ["mcc_code", "description"]

print(mcc_codes.head())
# Out:
#    mcc_code                           description
# 0      5812         Eating Places and Restaurants
# 1      5541                      Service Stations
# 2      7996  Amusement Parks, Carnivals, Circuses
# 3      5411          Grocery Stores, Supermarkets
# 4      4784                 Tolls and Bridge Fees

# %%
users_data= pd.read_csv(os.path.join(path, 'users_data.csv'))

# %%
cards_data = pd.read_csv(os.path.join(path, 'cards_data.csv'))

# %%
transactions_data = pd.read_csv(os.path.join(path, 'transactions_data.csv'), nrows=100000)
#train_fraud_labels = pd.read(os.path.join(path, 'train_fraud_labels'))

# %%
temp  = pd.read_json(os.path.join(path, 'train_fraud_labels.json'))
temp.shape
# Out:
# (8914963, 1)

# %%
temp.reset_index(inplace = True)

# %%
temp.columns
# Out:
# Index(['index', 'target'], dtype='object')

# %%
#temp = temp.reset_index()
temp = temp.rename(columns={'index':'id'})
transactions_data = transactions_data.merge (temp, on  = 'id', how ='left')

# %%
transactions_data.to_csv (os.path.join(path, 'transactions_target_data.csv'), index  =False)

# %%
del temp

# %% [markdown]
# ## Add user data

# %%
users_data.head(2)
# Out:
#      id  current_age  retirement_age  birth_year  birth_month  gender  \
# 0   825           53              66        1966           11  Female
# 1  1746           53              68        1966           12  Female
#
#                   address  latitude  longitude per_capita_income  \
# 0           462 Rose Lane     34.15    -117.76            $29278
# 1  3606 Federal Boulevard     40.76     -73.74            $37891
#
#   yearly_income total_debt  credit_score  num_credit_cards
# 0        $59696    $127613           787                 5
# 1        $77254    $191349           701                 5

# %%
transactions_data.head(2)
# Out:
#         id                 date  client_id  card_id   amount  \
# 0  7475327  2010-01-01 00:01:00       1556     2972  $-77.00
# 1  7475328  2010-01-01 00:02:00        561     4575   $14.57
#
#             use_chip  merchant_id merchant_city merchant_state      zip   mcc  \
# 0  Swipe Transaction        59935        Beulah             ND  58523.0  5499
# 1  Swipe Transaction        67570    Bettendorf             IA  52722.0  5311
#
#   errors target
# 0    NaN     No
# 1    NaN     No

# %%
users_data = users_data.rename(columns = {'id': 'client_id'})

# %%
transactions_data1  = transactions_data.merge(users_data, left_on ='client_id', right_on='client_id', validate ='m:1' )

# %%
transactions_data1.shape[1]-transactions_data.shape[1]-users_data.shape[1]
# Out:
# -1

# %%
'client_id' in transactions_data1.columns
# Out:
# True

# %%
transactions_data1.columns
# Out:
# Index(['id', 'date', 'client_id', 'card_id', 'amount', 'use_chip',
#        'merchant_id', 'merchant_city', 'merchant_state', 'zip', 'mcc',
#        'errors', 'target', 'current_age', 'retirement_age', 'birth_year',
#        'birth_month', 'gender', 'address', 'latitude', 'longitude',
#        'per_capita_income', 'yearly_income', 'total_debt', 'credit_score',
#        'num_credit_cards'],
#       dtype='object')

# %%
#transactions_data1.mcc.value_counts(dropna = False)

# %%
cards_data.head(2)
# Out:
#      id  client_id card_brand card_type       card_number  expires  cvv  \
# 0  4524        825       Visa     Debit  4344676511950444  12/2022  623
# 1  2731        825       Visa     Debit  4956965974959986  12/2020  393
#
#   has_chip  num_cards_issued credit_limit acct_open_date  \
# 0      YES                 2       $24295        09/2002
# 1      YES                 2       $21968        04/2014
#
#    year_pin_last_changed card_on_dark_web
# 0                   2008               No
# 1                   2014               No

# %%
cards_data.card_number.nunique(), cards_data.shape
# Out:
# (6146, (6146, 13))

# %%
transactions_data.head(1)
# Out:
#         id                 date  client_id  card_id   amount  \
# 0  7475327  2010-01-01 00:01:00       1556     2972  $-77.00
#
#             use_chip  merchant_id merchant_city merchant_state      zip   mcc  \
# 0  Swipe Transaction        59935        Beulah             ND  58523.0  5499
#
#   errors target
# 0    NaN     No

# %% [markdown]
# ## Add cards data

# %%
cards_data = cards_data.rename(columns={'id':'card_id'})

# %%
cards_data = cards_data.drop('client_id', axis = 1)

# %%
transactions_data2  = transactions_data1.merge(cards_data, left_on ='card_id', right_on='card_id', validate ='m:1' )

# %%
transactions_data2.shape[1]-transactions_data1.shape[1]-cards_data.shape[1]
# Out:
# -1

# %%
transactions_data2.columns
# Out:
# Index(['id', 'date', 'client_id', 'card_id', 'amount', 'use_chip',
#        'merchant_id', 'merchant_city', 'merchant_state', 'zip', 'mcc',
#        'errors', 'target', 'current_age', 'retirement_age', 'birth_year',
#        'birth_month', 'gender', 'address', 'latitude', 'longitude',
#        'per_capita_income', 'yearly_income', 'total_debt', 'credit_score',
#        'num_credit_cards', 'card_brand', 'card_type', 'card_number', 'expires',
#        'cvv', 'has_chip', 'num_cards_issued', 'credit_limit', 'acct_open_date',
#        'year_pin_last_changed', 'card_on_dark_web'],
#       dtype='object')

# %%
transactions_data2.target.value_counts(dropna=False)
# Out:
# target
# No     67124
# NaN    32769
# Yes      107
# Name: count, dtype: int64

# %%
#transactions_data2.target=transactions_data3.target.fillna('No')

# %%
transactions_data2.to_csv (os.path.join(path, 'transactions_final__data.csv'), index  =False)

# %%
transactions_data2.to_csv ('/home/coder/agent-bootcamp/tests/tool_tests/example_files/data.csv', index  =False)

# %%
transactions_data2 = pd.read_csv('/home/coder/agent-bootcamp/tests/tool_tests/example_files/data.csv')

# %%
bad = transactions_data2[transactions_data2.target=='Yes']
print (bad.shape)
good = transactions_data2[transactions_data2.target=='No']
print (good.shape)
# Out:
# (107, 37)
# (67124, 37)

# %%
transactions_data3  = pd.concat ([bad, good.sample (10000)], axis =0)

# %%
transactions_data3.shape
# Out:
# (10107, 37)

# %%
transactions_data3.to_csv ('/home/coder/agent-bootcamp/tests/tool_tests/example_files/data_b.csv', index  =False)

# %%
transactions_data3.target.value_counts(dropna=False)
# Out:
# target
# No     10000
# Yes      107
# Name: count, dtype: int64

# %%
transactions_data3.head()
# Out:
#             id                 date  client_id  card_id   amount  \
# 3459   7479444  2010-01-01 23:56:00        126     5497    $0.19
# 9526   7486725  2010-01-03 20:58:00        126     5497  $339.00
# 12989  7490901  2010-01-04 23:30:00        720     4136    $4.45
# 13000  7490914  2010-01-04 23:48:00        720     4136    $7.19
# 13081  7491008  2010-01-05 02:34:00       1644     3444    $8.76
#
#                  use_chip  merchant_id merchant_city merchant_state  zip  ...  \
# 3459   Online Transaction        90999        ONLINE            NaN  NaN  ...
# 9526   Online Transaction         3558        ONLINE            NaN  NaN  ...
# 12989  Online Transaction        24504        ONLINE            NaN  NaN  ...
# 13000  Online Transaction        38602        ONLINE            NaN  NaN  ...
# 13081  Online Transaction        21776        ONLINE            NaN  NaN  ...
#
#        card_type       card_number  expires  cvv  has_chip  num_cards_issued  \
# 3459       Debit  5110177937842500  04/2023  932       YES                 1
# 9526       Debit  5110177937842500  04/2023  932       YES                 1
# 12989      Debit  5549447642972376  08/2021  647       YES                 1
# 13000      Debit  5549447642972376  08/2021  647       YES                 1
# 13081     Credit  4715738219735937  07/2023  643       YES                 1
#
#        credit_limit acct_open_date year_pin_last_changed  card_on_dark_web
# 3459         $13555        11/2007                  2011                No
# 9526         $13555        11/2007                  2011                No
# 12989          $974        08/2004                  2008                No
# 13000          $974        08/2004                  2008                No
# 13081        $10900        06/2009                  2009                No
#
# [5 rows x 37 columns]
